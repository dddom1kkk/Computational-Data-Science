# %%
# %run monthly_totals.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Downloads/e1/monthly_totals.py in ?()
#     104     np.savez('monthdata.npz', totals=totals.values, counts=counts.values)
#     105
#     106
#     107 if __name__ == '__main__':
# --> 108     main()
#
# ~/Downloads/e1/monthly_totals.py in ?()
#      99 def main():
#     100     data = get_precip_data()
# --> 101     totals, counts = pivot_months_pandas(data)
#     102     totals.to_csv('totals.csv')
#     103     counts.to_csv('counts.csv')
#     104     np.savez('monthdata.npz', totals=totals.values, counts=counts.values)
#
# ~/Downloads/e1/monthly_totals.py in ?(data)
#      21     temp = data.copy(deep=True)
#      22
#      23     date = temp['date']
#      24
# ---> 25     month = temp.apply(date_to_month)
#      26
#      27     temp.insert(2, "month", month)
#      28
#
# ...
